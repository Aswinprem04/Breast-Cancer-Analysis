# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
names1 = ['Id', 'Outcome', 'radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean',
         'smoothness_mean', 'compactness_mean', 'concavity_mean', 'concave points_mean',
          'symmetry_mean', 'fractal_dimension_mean', 'radius_se', 'texture_se', 'perimeter_se',
          'area_se', 'smoothness_se', 'compactness_se', 'concavity_se', 'concave points_se',
          'symmetry_se', 'fractal_dimension_se', 'radius_worst', 'texture_worst', 'perimeter_worst',
          'area_worst', 'smoothness_worst', 'compactness_worst', 'concavity_worst',
           'concave points_worst', 'symmetry_worst', 'fractal_dimension_worst']


names2=['Id','Outcome','Time','radius1','texture1','perimeter1','area1','smoothness1','compactness1','concavity1','concave_points1','symmetry1','fractal_dimension1',
        'radius2','texture2','perimeter2','area2','smoothness2','compactness2','concavity2','concave_points2','symmetry2','fractal_dimension2',
        'radius3','texture3','perimeter3','area3','smoothness3','compactness3','concavity3','concave_points3','symmetry3','fractal_dimension3',
        'Tumor size','Lymph node status']

# %%
df1 = pd.read_csv('Breast Cancer Wisconsin (Diagnostic) -wbc.csv', names=names1)
df2 = pd.read_csv('prognostic-wbc.csv', names=names2)

# %%
df1
# Out:
#            Id Outcome  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302       M        17.99         10.38          122.80     1001.0
# 1      842517       M        20.57         17.77          132.90     1326.0
# 2    84300903       M        19.69         21.25          130.00     1203.0
# 3    84348301       M        11.42         20.38           77.58      386.1
# 4    84358402       M        20.29         14.34          135.10     1297.0
# ..        ...     ...          ...           ...             ...        ...
# 564    926424       M        21.56         22.39          142.00     1479.0
# 565    926682       M        20.13         28.25          131.20     1261.0
# 566    926954       M        16.60         28.08          108.30      858.1
# 567    927241       M        20.60         29.33          140.10     1265.0
# 568     92751       B         7.76         24.54           47.92      181.0
#
# ...

# %%
df2
# Out:
#          Id Outcome  Time  radius1  texture1  perimeter1   area1  smoothness1  \
# 0    119513       N    31    18.02     27.60      117.50  1013.0      0.09489
# 1      8423       N    61    17.99     10.38      122.80  1001.0      0.11840
# 2    842517       N   116    21.37     17.44      137.50  1373.0      0.08836
# 3    843483       N   123    11.42     20.38       77.58   386.1      0.14250
# 4    843584       R    27    20.29     14.34      135.10  1297.0      0.10030
# ..      ...     ...   ...      ...       ...         ...     ...          ...
# 193  942640       N    10    22.52     21.92      146.90  1597.0      0.07592
# 194  943471       N     8    15.44     31.18      101.00   740.4      0.09399
# 195   94547       N    12    17.17     29.19      110.00   915.3      0.08952
# 196  947204       R     3    21.42     22.84      145.00  1440.0      0.10700
# 197  947489       N     6    16.70     28.13      110.30   885.4      0.08896
#
# ...

# %%
df2.isnull().sum()
# Out:
# Id                    0
# Outcome               0
# Time                  0
# radius1               0
# texture1              0
# perimeter1            0
# area1                 0
# smoothness1           0
# compactness1          0
# concavity1            0
# concave_points1       0
# symmetry1             0
# fractal_dimension1    0
# radius2               0
# texture2              0
# perimeter2            0
# area2                 0
# smoothness2           0
# compactness2          0
# concavity2            0
# concave_points2       0
# symmetry2             0
# fractal_dimension2    0
# radius3               0
# texture3              0
# perimeter3            0
# area3                 0
# smoothness3           0
# compactness3          0
# concavity3            0
# concave_points3       0
# symmetry3             0
# fractal_dimension3    0
# Tumor size            0
# Lymph node status     0
# dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Id                       569 non-null    int64
#  1   Outcome                  569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 198 entries, 0 to 197
# Data columns (total 35 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Id                  198 non-null    int64
#  1   Outcome             198 non-null    object
#  2   Time                198 non-null    int64
#  3   radius1             198 non-null    float64
#  4   texture1            198 non-null    float64
#  5   perimeter1          198 non-null    float64
#  6   area1               198 non-null    float64
#  7   smoothness1         198 non-null    float64
#  8   compactness1        198 non-null    float64
#  9   concavity1          198 non-null    float64
#  10  concave_points1     198 non-null    float64
#  11  symmetry1           198 non-null    float64
#  12  fractal_dimension1  198 non-null    float64
#  13  radius2             198 non-null    float64
#  14  texture2            198 non-null    float64
# ...

# %%
#combine the datasets
df = pd.concat([df1, df2], ignore_index=True)
df.head()
# Out:
#          Id Outcome  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302       M        17.99         10.38          122.80     1001.0
# 1    842517       M        20.57         17.77          132.90     1326.0
# 2  84300903       M        19.69         21.25          130.00     1203.0
# 3  84348301       M        11.42         20.38           77.58      386.1
# 4  84358402       M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  perimeter3  area3  smoothness3  compactness3  concavity3  \
# ...

# %%
df.drop(columns=['Id'], inplace=True)

# %%
df.columns
# Out:
# Index(['Outcome', 'radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean',
#        'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst', 'Time', 'radius1',
#        'texture1', 'perimeter1', 'area1', 'smoothness1', 'compactness1',
#        'concavity1', 'concave_points1', 'symmetry1', 'fractal_dimension1',
#        'radius2', 'texture2', 'perimeter2', 'area2', 'smoothness2',
#        'compactness2', 'concavity2', 'concave_points2', 'symmetry2',
# ...

# %% [markdown]
# ### EDA

# %%
print("Number of instances",df.shape[0])
print("\nNumber of attributes",df.shape[1])
print("\nNumber of unique values\n",df.nunique())
print("\nNumber of null values\n",df.isnull().sum())
print("\nNumber of predicted values\n",df['Outcome'].value_counts())
# Out:
# Number of instances 767
#
# Number of attributes 64
#
# Number of unique values
#  Outcome                 4
# radius_mean           456
# texture_mean          479
# perimeter_mean        522
# area_mean             539
#                      ...
# concave_points3       185
# symmetry3             192
# fractal_dimension3    189
# Tumor size             39
# Lymph node status      23
# Length: 64, dtype: int64
#
# Number of null values
#  Outcome                 0
# radius_mean           198
# texture_mean          198
# perimeter_mean        198
# area_mean             198
#                      ...
# concave_points3       569
# symmetry3             569
# fractal_dimension3    569
# Tumor size            569
# Lymph node status     569
# Length: 64, dtype: int64
#
# Number of predicted values
#  B    357
# M    212
# N    151
# R     47
# Name: Outcome, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 767 entries, 0 to 766
# Data columns (total 64 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Outcome                  767 non-null    object
#  1   radius_mean              569 non-null    float64
#  2   texture_mean             569 non-null    float64
#  3   perimeter_mean           569 non-null    float64
#  4   area_mean                569 non-null    float64
#  5   smoothness_mean          569 non-null    float64
#  6   compactness_mean         569 non-null    float64
#  7   concavity_mean           569 non-null    float64
#  8   concave points_mean      569 non-null    float64
#  9   symmetry_mean            569 non-null    float64
#  10  fractal_dimension_mean   569 non-null    float64
#  11  radius_se                569 non-null    float64
#  12  texture_se               569 non-null    float64
# ...

# %%
df.describe()
# Out:
#        radius_mean  texture_mean  perimeter_mean    area_mean  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# ...

# %%
df.shape
# Out:
# (767, 64)

# %%
df.isnull().sum()
# Out:
# Outcome                 0
# radius_mean           198
# texture_mean          198
# perimeter_mean        198
# area_mean             198
#                      ...
# concave_points3       569
# symmetry3             569
# fractal_dimension3    569
# Tumor size            569
# Lymph node status     569
# Length: 64, dtype: int64

# %% [markdown]
# ### Required Plotting

# %%
#Plotting NaN values
missing_counts = df.isnull().sum()
plt.figure(figsize=(10, 6))
b = sns.barplot(x=missing_counts.index, y=missing_counts.values)
b.set(xlabel='Columns', ylabel='Number of Missing Values')
plt.title('Missing Values by Column')
plt.xticks(rotation=90, fontsize=8)

print(df.isnull().sum())
plt.show()
# Out:
# Outcome                 0
# radius_mean           198
# texture_mean          198
# perimeter_mean        198
# area_mean             198
#                      ...
# concave_points3       569
# symmetry3             569
# fractal_dimension3    569
# Tumor size            569
# Lymph node status     569
# Length: 64, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df1 = df.apply(le.fit_transform)

print(df1)
# Out:
#      Outcome  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          1          370             1             455        452
# 1          1          426           186             486        513
# 2          1          406           324             478        487
# 3          1           98           297             164         95
# 4          1          418            60             493        506
# ..       ...          ...           ...             ...        ...
# 762        2          456           479             522        539
# 763        2          456           479             522        539
# 764        2          456           479             522        539
# 765        3          456           479             522        539
# 766        2          456           479             522        539
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0                444               531             521                  526
# ...

# %%
print(df1.isnull().sum())
# Out:
# Outcome               0
# radius_mean           0
# texture_mean          0
# perimeter_mean        0
# area_mean             0
#                      ..
# concave_points3       0
# symmetry3             0
# fractal_dimension3    0
# Tumor size            0
# Lymph node status     0
# Length: 64, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x='Outcome',data=df1,palette=['orange','blue','green','red'])
plt.show()
# Out:
# <ipython-input-20-fbc8bf5d61b4>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Outcome',data=df1,palette=['orange','blue','green','red'])

# %%
plt.pie(df1['Outcome'].value_counts(),autopct='%.1f%%', labels=['Benign', 'Malignant','Non-recur','Recur'])
plt.show()

# %%
# Pair Plot
rad_cols = ['Outcome', 'radius_mean', 'radius_se', 'radius_worst']
sns.pairplot(data=df1[rad_cols], hue='Outcome', palette='Set1')

# %%
smooth_cols = ['Outcome', 'smoothness_mean', 'smoothness_se', 'smoothness_worst']
sns.pairplot(data=df1[smooth_cols], hue='Outcome', palette='Set1')

# %%
texture_cols = ['Outcome', 'texture_mean', 'texture_se', 'texture_worst']
sns.pairplot(data=df1[texture_cols], hue='Outcome', palette='Set1')

# %%
cols = ['Outcome', 'radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean', 'smoothness_mean',
        'compactness_mean', 'concavity_mean','concave points_mean', 'symmetry_mean', 'fractal_dimension_mean']
sns.pairplot(data=df1[cols], hue='Outcome', palette='Set1')
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ### Heatmap with Correlation Matrix

# %%
cm = df.drop(['Outcome'],axis=1)

# %%
#correlation
f,ax = plt.subplots(figsize=(30, 30))
sns.heatmap(cm.corr(), cmap='Blues',annot=True, linewidths=.5, fmt= '.1f',ax=ax)
plt.xticks(fontsize=11,rotation=70)
plt.show()
# Out:
# <ipython-input-27-4091243f6e94>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(cm.corr(), cmap='Blues',annot=True, linewidths=.5, fmt= '.1f',ax=ax)

# %%
# Heatmap for mean values
plt.figure(figsize=(5,5))
sns.heatmap(data=cm.iloc[:,0:10].corr())
# Out:
# <Axes: >

# %%
#Heatmap for Standard Error values
plt.figure(figsize=(5,5))
sns.heatmap(data=cm.iloc[:,11:20].corr())
# Out:
# <Axes: >

# %%
#Heatmap for with worst values
plt.figure(figsize=(5,5))
sns.heatmap(data=cm.iloc[:,21:30].corr())
# Out:
# <Axes: >

# %%
#Train-test-split
X =  df1.drop(columns=['Outcome'])
y =df1['Outcome']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %% [markdown]
# ### Feature Importance

# %%
#Random forest
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf.fit(X,y)
# Out:
# RandomForestClassifier()

# %%
feature_importance = rf.feature_importances_

feature_names = df1.columns[1:]

feature_importance_combined = pd.DataFrame({
    'Feature': list(feature_names),
    'Importance': list(feature_importance)
    })

top_features = feature_importance_combined.nlargest(10, ['Importance'])
print(top_features)

plt.figure(figsize=(10, 6))
plt.barh(top_features['Feature'], top_features['Importance'])
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.title('Top 10 Feature Importance')
plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#                  Feature  Importance
# 22       perimeter_worst    0.069002
# 27  concave points_worst    0.061661
# 0            radius_mean    0.057871
# 23            area_worst    0.051475
# 7    concave points_mean    0.049949
# 6         concavity_mean    0.049485
# 2         perimeter_mean    0.045167
# 3              area_mean    0.043847
# 20          radius_worst    0.041058
# 26       concavity_worst    0.022600

# %%
y_predict = rf.predict(X_test)

# %%
rf.score(X_test,y_test)
# Out:
# 1.0

# %%
from sklearn import metrics
print(metrics.accuracy_score(y_test, y_predict))
# Out:
# 1.0

# %%
from sklearn.metrics import confusion_matrix
y_test = pd.Series(y_test)
y_predict = pd.Series(y_predict)
cm1 = confusion_matrix(y_test, y_predict)

sns.heatmap(cm1, annot=True)
plt.xlabel("Predicted labels")
plt.ylabel("True labels")
plt.title("Confusion Matrix")

plt.show()

# %% [markdown]
# ### Comparing ML algorithms

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
import warnings
warnings.filterwarnings('ignore')

# %%
models = []
models.append(('LB' , LogisticRegression()))
models.append(('LDA' , LinearDiscriminantAnalysis()))
models.append(('KNN' , KNeighborsClassifier()))
models.append(('CART' , DecisionTreeClassifier()))
models.append(('NB' , GaussianNB()))
models.append(('SVM' , SVC()))

# %%
results = []
names = []
scoring = 'accuracy'
for name, model in models:
    kfold = KFold(n_splits=10)
    cv_results = cross_val_score(model, X, y, cv=kfold, scoring=scoring)
    results.append(cv_results)
    names.append(name)
    msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std())
    print(name, cv_results.mean(), cv_results.std())
# Out:
# LB 0.8911825017088175 0.11045185622453164
# LDA 0.8857997265892003 0.14427355076317197
# KNN 0.8977443609022556 0.10391195983803987
# CART 0.838943950786056 0.11946526941292152
# NB 0.8545625427204374 0.14328135549614426
# SVM 0.9225563909774437 0.08942403117771756

# %%
# boxplot algorithm comparison
from matplotlib import pyplot
fig = pyplot.figure()
fig.suptitle('Algorithm Comparison')
ax = fig.add_subplot(111)
pyplot.boxplot(results)
ax.set_xticklabels(names)
pyplot.show()
